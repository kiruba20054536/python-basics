# %%
for i in range(1,3):
    print("Week:",i)
    for j in range(1,8):
        print("Day:",j)
# Out:
# Week: 1
# Day: 1
# Day: 2
# Day: 3
# Day: 4
# Day: 5
# Day: 6
# Day: 7
# Week: 2
# Day: 1
# Day: 2
# Day: 3
# Day: 4
# Day: 5
# Day: 6
# Day: 7

# %%
n=5
for i in range(1,n+1):
    for j in range(1,i+1):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(n,0,-1):
    for j in range(1,i+1):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *
