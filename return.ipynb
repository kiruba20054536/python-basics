# %%
def painter():
    return "I am painter"
a=painter()
print(a) # if we give return the we can store it to another variable and we can store it, modify it, reuse it
# Out:
# I am painter

# %%
def painter():
    print("I am painter")
a=painter() 
print(a) # Function returns None We cannot reuse the value
# Out:
# I am painter
# None

# %% [markdown]
# 5) Set s_username="kiruba", s_password="123". Get input for uname and password. Create a function called validate. If uname and password matches the function should return true else false.

# %%
s_username="kiruba"
s_password="123"
uname=input("Enter user name:")
password=input("Enter password:")
def validate():
    if (s_username==uname and s_password == password):
        return True
    else:
        return False
validate()
# Out:
# Enter user name: kiruba
# Enter password: 456
# False

# %% [markdown]
# 6. Get input for a and b and function called add() which should return the sum of a and b and multiply that sum with c.

# %%
def add(a,b):
    return a+b
a= int(input("Enter a number:"))
b= int(input("Enter another number:"))
c= int(input("Enter another number:"))
added= add(a,b)
ans=added*c
print(ans)
# Out:
# Enter a number: 5
# Enter another number: 6
# Enter another number: 8
# 88
